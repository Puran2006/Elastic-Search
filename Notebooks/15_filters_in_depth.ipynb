# %% [markdown]
# ## Documentation
#
# To read more about filters, checkout the docs [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/filter-search-results.html).
#
# ![filters_in_depth](../images/filters_in_depth.png)

# %% [markdown]
# ## Connect to ElasticSearch

# %%
from pprint import pprint
from elasticsearch import Elasticsearch

es = Elasticsearch('http://localhost:9200')
client_info = es.info()
print('Connected to Elasticsearch!')
pprint(client_info.body)
# Out:
# Connected to Elasticsearch!
# {'cluster_name': 'docker-cluster',
#  'cluster_uuid': 'WpOI-sfBSXe9aaVkWGIQnQ',
#  'name': '61929d733ddf',
#  'tagline': 'You Know, for Search',
#  'version': {'build_date': '2025-12-16T10:09:08.849001802Z',
#              'build_flavor': 'default',
#              'build_hash': 'd8972a71dbbd64ff17f2f4dba9ca2c3fe09fb100',
#              'build_snapshot': False,
#              'build_type': 'docker',
#              'lucene_version': '10.3.2',
#              'minimum_index_compatibility_version': '8.0.0',
#              'minimum_wire_compatibility_version': '8.19.0',
#              'number': '9.2.3'}}

# %% [markdown]
# ## Index data

# %%
import json

from pprint import pprint

es.indices.delete(index='my_index', ignore_unavailable=True)
es.indices.create(index='my_index')

operations = []
clothes_documents = json.load(open("../data/clothes.json"))

for document in clothes_documents:
    operations.append({'index': {'_index': 'my_index'}})
    operations.append(document)

response = es.bulk(operations=operations)
pprint(response.body)
# Out:
# {'errors': False,
#  'items': [{'index': {'_id': 'eTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 0,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ejNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 1,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ezNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 2,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'fDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 3,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'fTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 4,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'fjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 5,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'fzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 6,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'gDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 7,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'gTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 8,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'gjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 9,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'gzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 10,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'hDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 11,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'hTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 12,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'hjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 13,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'hzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 14,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'iDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 15,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'iTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 16,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ijNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 17,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'izNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 18,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'jDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 19,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'jTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 20,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'jjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 21,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'jzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 22,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'kDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 23,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'kTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 24,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'kjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 25,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'kzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 26,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'lDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 27,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'lTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 28,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ljNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 29,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'lzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 30,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'mDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 31,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'mTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 32,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'mjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 33,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'mzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 34,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'nDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 35,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'nTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 36,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'njNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 37,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'nzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 38,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'oDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 39,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'oTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 40,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ojNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 41,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ozNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 42,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'pDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 43,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'pTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 44,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'pjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 45,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'pzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 46,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'qDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 47,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'qTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 48,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'qjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 49,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'qzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 50,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'rDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 51,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'rTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 52,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'rjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 53,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'rzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 54,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'sDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 55,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'sTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 56,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'sjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 57,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'szNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 58,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'tDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 59,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'tTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 60,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'tjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 61,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'tzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 62,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'uDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 63,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'uTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 64,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'ujNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 65,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'uzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 66,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'vDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 67,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'vTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 68,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'vjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 69,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'vzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 70,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'wDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 71,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'wTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 72,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'wjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 73,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'wzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 74,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'xDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 75,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'xTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 76,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'xjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 77,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'xzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 78,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'yDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 79,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'yTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 80,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'yjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 81,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'yzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 82,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'zDNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 83,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'zTNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 84,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'zjNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 85,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': 'zzNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 86,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '0DNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 87,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '0TNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 88,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '0jNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 89,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '0zNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 90,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '1DNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 91,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '1TNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 92,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '1jNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 93,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '1zNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 94,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '2DNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 95,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '2TNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 96,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '2jNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 97,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '2zNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 98,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}},
#            {'index': {'_id': '3DNtCJwBGz81Nh7gm-r6',
#                       '_index': 'my_index',
#                       '_primary_term': 1,
#                       '_seq_no': 99,
#                       '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#                       '_version': 1,
#                       'result': 'created',
#                       'status': 201}}],
#  'took': 200}

# %%
count = es.count(index='my_index')
print('Number of documents in index:', count.body['count'])
# Out:
# Number of documents in index: 100

# %% [markdown]
# ## Simple filters

# %% [markdown]
# Previously, we learned about compound queries. Using a boolean query, you can apply filters to narrow down documents based on specific criteria. In this simple example, we filter documents to keep only those where the brand is Adidas.

# %%
response = es.search(
    index="my_index",
    body={
        "query": {
            "bool": {
                "filter": [
                    {
                        "term": {
                            "brand": "adidas"
                        }
                    }
                ]
            }
        },
        "size": 100
    },
)

hits = response.body['hits']['hits']
print(f"Found {len(hits)} documents")
# Out:
# Found 23 documents

# %% [markdown]
# Here, we apply multiple filters using an AND operation to retain documents where the brand is Adidas and the color is yellow.

# %%
response = es.search(
    index="my_index",
    body={
        "query": {
            "bool": {
                "filter": [
                    {
                        "term": {
                            "color": "yellow"
                        }
                    },
                    {
                        "term": {
                            "brand": "adidas"
                        }
                    }
                ]
            }
        },
    },
)

hits = response.body['hits']['hits']
print(f"Found {len(hits)} documents")
# Out:
# Found 6 documents

# %% [markdown]
# ## Post filters

# %% [markdown]
# In this example, we'll explore the use of filters, aggregations, filtered aggregations, and post-filters.
#
# We start by narrowing our search to documents where the `brand` is `gucci`. Next, we apply aggregations to determine the document count for each color. We then define a filtered aggregation, `color_red`, which counts the models in documents where the color is `red`.
#
# Finally, a `post_filter` is used after performing the aggregations, refining the search results to include only documents with the color `red`.

# %%
response = es.search(
    index="my_index",
    body={
        "query": {
            "bool": {
                "filter": {
                    "term": {
                        "brand": "gucci"
                    }
                }
            }
        },
        "aggs": {
            "colors": {
                "terms": {
                    "field": "color.keyword"
                }
            },
            "color_red": {
                "filter": {
                    "term": {
                        "color.keyword": "red"
                    }
                },
                "aggs": {
                    "models": {
                        "terms": {
                            "field": "model.keyword"
                        }
                    }
                }
            }
        },
        "post_filter": {
            "term": {
                "color": "red"
            }
        },
        "size": 20
    }
)
pprint(response.body)
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'color_red': {'doc_count': 12,
#                                 'models': {'buckets': [{'doc_count': 3,
#                                                         'key': 'model_1'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_14'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_16'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_2'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_26'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_28'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_3'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_4'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_6'},
#                                                        {'doc_count': 1,
#                                                         'key': 'model_8'}],
#                                            'doc_count_error_upper_bound': 0,
#                                            'sum_other_doc_count': 0}},
#                   'colors': {'buckets': [{'doc_count': 12, 'key': 'red'},
#                                          {'doc_count': 8, 'key': 'blue'},
#                                          {'doc_count': 6, 'key': 'green'},
#                                          {'doc_count': 4, 'key': 'yellow'}],
#                              'doc_count_error_upper_bound': 0,
#                              'sum_other_doc_count': 0}},
#  'hits': {'hits': [{'_id': 'bhiy8ZIB0kQCMOUuLgAS',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'cBiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_3'}},
#                    {'_id': 'chiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'dxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_4'}},
#                    {'_id': 'ehiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_1'}},
#                    {'_id': 'gxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_2'}},
#                    {'_id': 'kxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_28'}},
#                    {'_id': 'mxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_6'}},
#                    {'_id': 'oxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_14'}},
#                    {'_id': 'rxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_26'}},
#                    {'_id': 'uxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_8'}},
#                    {'_id': 'wxiy8ZIB0kQCMOUuLgAT',
#                     '_index': 'my_index',
#                     '_score': 0.0,
#                     '_source': {'brand': 'gucci',
#                                 'color': 'red',
#                                 'model': 'model_16'}}],
#           'max_score': 0.0,
#           'total': {'relation': 'eq', 'value': 12}},
#  'timed_out': False,
#  'took': 5}

# %% [markdown]
# The `colors_aggregation` variable holds the count of documents associated with each color, as returned by the aggregation query.

# %%
colors_aggregation = response.body['aggregations']['colors']['buckets']
pprint(colors_aggregation)
# Out:
# [{'doc_count': 12, 'key': 'red'},
#  {'doc_count': 8, 'key': 'blue'},
#  {'doc_count': 6, 'key': 'green'},
#  {'doc_count': 4, 'key': 'yellow'}]

# %% [markdown]
# The `color_red_aggregation` variable contains the results from the `color_red` filtered aggregation, which includes the count of models specifically for documents where the color is `red`.

# %%
color_red_aggregation = response.body['aggregations']['color_red']['models']['buckets']
pprint(color_red_aggregation)
# Out:
# [{'doc_count': 3, 'key': 'model_1'},
#  {'doc_count': 1, 'key': 'model_14'},
#  {'doc_count': 1, 'key': 'model_16'},
#  {'doc_count': 1, 'key': 'model_2'},
#  {'doc_count': 1, 'key': 'model_26'},
#  {'doc_count': 1, 'key': 'model_28'},
#  {'doc_count': 1, 'key': 'model_3'},
#  {'doc_count': 1, 'key': 'model_4'},
#  {'doc_count': 1, 'key': 'model_6'},
#  {'doc_count': 1, 'key': 'model_8'}]

# %% [markdown]
# To get the search results after the post-filter has been applied, we access the `hits` from `response.body['hits']['hits']`. This allows us to iterate through each result and display details such as the shirt's brand, color, and model.

# %%
hits = response.body['hits']['hits']
for hit in hits:
    print(f"""Shirt brand: {hit['_source']['brand']}, color: {
          hit['_source']['color']}, and model: {hit['_source']['model']}""")
# Out:
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: red, and model: model_3
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: red, and model: model_4
# Shirt brand: gucci, color: red, and model: model_1
# Shirt brand: gucci, color: red, and model: model_2
# Shirt brand: gucci, color: red, and model: model_28
# Shirt brand: gucci, color: red, and model: model_6
# Shirt brand: gucci, color: red, and model: model_14
# Shirt brand: gucci, color: red, and model: model_26
# Shirt brand: gucci, color: red, and model: model_8
# Shirt brand: gucci, color: red, and model: model_16
